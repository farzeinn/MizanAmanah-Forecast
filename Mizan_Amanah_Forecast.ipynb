# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ##get data

# %%
# !gdown --id 1omd2SJfBQKu-7j8D2bvxtghZiOX5bXwR
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1omd2SJfBQKu-7j8D2bvxtghZiOX5bXwR
# To: /content/Online Donation.zip
# 100% 443k/443k [00:00<00:00, 57.6MB/s]

# %%
import zipfile

folder_path = '/content/Online Donation.zip'
openZip = zipfile.ZipFile(folder_path, 'r')
openZip.extractall('/content')
openZip.close()

# %% [markdown]
# ##read dataset

# %% [markdown]
# gd = guest donasi<br>ud = user donasi<br>gz = guest zakat<br>uz = user zakat

# %%
gd_jan = pd.read_csv('/content/Online Donation/Guest/Donasi/Januari-donasi-guest.csv')
gd_feb = pd.read_csv('/content/Online Donation/Guest/Donasi/Februari-donasi-guest.csv')
gd_mar = pd.read_csv('/content/Online Donation/Guest/Donasi/Maret-donasi-guest.csv')
gd_apr = pd.read_csv('/content/Online Donation/Guest/Donasi/April-donasi-guest.csv')
gd_may = pd.read_csv('/content/Online Donation/Guest/Donasi/Mei-donasi-guest.csv')
gd_jun = pd.read_csv('/content/Online Donation/Guest/Donasi/Juni-donasi-guest.csv')
gd_jul = pd.read_csv('/content/Online Donation/Guest/Donasi/Juli-donasi-guest.csv')
gd_aug = pd.read_csv('/content/Online Donation/Guest/Donasi/Agustus-donasi-guest.csv')
gd_sep = pd.read_csv('/content/Online Donation/Guest/Donasi/September-donasi-guest.csv')
gd_oct = pd.read_csv('/content/Online Donation/Guest/Donasi/Oktober-donasi-guest.csv')
gd_nov = pd.read_csv('/content/Online Donation/Guest/Donasi/November-donasi-guest.csv')
gd_des = pd.read_csv('/content/Online Donation/Guest/Donasi/Desember-donasi-guest.csv')

ud_jan = pd.read_csv('/content/Online Donation/Users/Donasi/Januari-donasi-users.csv')
ud_feb = pd.read_csv('/content/Online Donation/Users/Donasi/Februari-donasi-users.csv')
ud_mar = pd.read_csv('/content/Online Donation/Users/Donasi/Maret-donasi-users.csv')
ud_apr = pd.read_csv('/content/Online Donation/Users/Donasi/April-donasi-users.csv')
ud_may = pd.read_csv('/content/Online Donation/Users/Donasi/Mei-donasi-users.csv')
ud_jun = pd.read_csv('/content/Online Donation/Users/Donasi/Juni-donasi-users.csv')
ud_jul = pd.read_csv('/content/Online Donation/Users/Donasi/Juli-donasi-users.csv')
ud_aug = pd.read_csv('/content/Online Donation/Users/Donasi/Agustus-donasi-users.csv')
ud_sep = pd.read_csv('/content/Online Donation/Users/Donasi/September-donasi-users.csv')
ud_oct = pd.read_csv('/content/Online Donation/Users/Donasi/Oktober-donasi-users.csv')
ud_nov = pd.read_csv('/content/Online Donation/Users/Donasi/November-donasi-users.csv')
ud_des = pd.read_csv('/content/Online Donation/Users/Donasi/Desember-donasi-users.csv')

# Guest Zakat DataFrame
df_gz = pd.read_csv('/content/Online Donation/Guest/Zakat/Januari-sampai-desember-zakat-guest.csv')

uz_jan = pd.read_csv('/content/Online Donation/Users/Zakat/Januari-zakat-users.csv')
uz_feb = pd.read_csv('/content/Online Donation/Users/Zakat/Februari-zakat-users.csv')
uz_mar = pd.read_csv('/content/Online Donation/Users/Zakat/Maret-zakat-users.csv')
uz_apr = pd.read_csv('/content/Online Donation/Users/Zakat/April-zakat-users.csv')
uz_may = pd.read_csv('/content/Online Donation/Users/Zakat/Mei-zakat-users.csv')
uz_jun = pd.read_csv('/content/Online Donation/Users/Zakat/Juni-zakat-users.csv')
uz_jul = pd.read_csv('/content/Online Donation/Users/Zakat/Juli-zakat-users.csv')
uz_aug = pd.read_csv('/content/Online Donation/Users/Zakat/Agustus-zakat-users.csv')
uz_sep = pd.read_csv('/content/Online Donation/Users/Zakat/September-zakat-users.csv')
uz_oct = pd.read_csv('/content/Online Donation/Users/Zakat/Oktober-zakat-users.csv')
uz_nov = pd.read_csv('/content/Online Donation/Users/Zakat/November-zakat-users.csv')
uz_des = pd.read_csv('/content/Online Donation/Users/Zakat/Desember-zakat-users.csv')

# %% [markdown]
# #Data Donasi

# %%
def guestPerBulan(data):
  data = data.copy()
  data = data.drop(['ID', 'nama_lengkap', 'platform', 'judul', 'status', 'metode_pembayaran'], axis=1)
  data['tanggal'] = data['tanggal'].str.slice(start=0, stop=10)
  data = data.groupby('tanggal')['total_donasi'].sum().reset_index()
  data = data.sort_values(by='tanggal', ascending=True)
  data.index = pd.DatetimeIndex(data.tanggal)
  data = data.drop(['tanggal'], axis=1)
  data = data.reset_index()
  data = data.rename(columns={'index':'tanggal'})
  return data

def usersPerBulan(data):
  data = data.copy()
  data = data.drop(['ID', 'name', 'platform', 'judul', 'status', 'metode_pembayaran'], axis=1)
  data['tanggal'] = data['tanggal'].str.slice(start=0, stop=10)
  data = data.groupby('tanggal')['total_donasi'].sum().reset_index()
  data = data.sort_values(by='tanggal', ascending=True)
  data.index = pd.DatetimeIndex(data.tanggal)
  data = data.drop(['tanggal'], axis=1)
  data = data.reset_index()
  data = data.rename(columns={'index':'tanggal'})
  return data

# %% [markdown]
# ##guest donasi

# %%
gd_jan = guestPerBulan(gd_jan)
gd_feb = guestPerBulan(gd_feb)
gd_mar = guestPerBulan(gd_mar)
gd_apr = guestPerBulan(gd_apr)
gd_may = guestPerBulan(gd_may)
gd_jun = guestPerBulan(gd_jun)
gd_jul = guestPerBulan(gd_jul)
gd_aug = guestPerBulan(gd_aug)
gd_sep = guestPerBulan(gd_sep)
gd_oct = guestPerBulan(gd_oct)
gd_nov = guestPerBulan(gd_nov)
gd_des = guestPerBulan(gd_des)

# %%
gd_month = [gd_jan, gd_feb, gd_mar, gd_apr, gd_may, gd_jun, gd_jul, gd_aug, gd_sep, gd_oct, gd_nov, gd_des]
print('Guest Donasi Before\n')
for i,x in enumerate(gd_month, start=1):
  print('bulan ke-',i,' jumlah hari', x['tanggal'].nunique())
# Out:
# Guest Donasi Before
#
# bulan ke- 1  jumlah hari 27
# bulan ke- 2  jumlah hari 28
# bulan ke- 3  jumlah hari 31
# bulan ke- 4  jumlah hari 29
# bulan ke- 5  jumlah hari 31
# bulan ke- 6  jumlah hari 26
# bulan ke- 7  jumlah hari 30
# bulan ke- 8  jumlah hari 30
# bulan ke- 9  jumlah hari 30
# bulan ke- 10  jumlah hari 31
# bulan ke- 11  jumlah hari 30
# bulan ke- 12  jumlah hari 6

# %% [markdown]
# ##user donasi

# %%
ud_jan = usersPerBulan(ud_jan)
ud_feb = usersPerBulan(ud_feb)
ud_mar = usersPerBulan(ud_mar)
ud_apr = usersPerBulan(ud_apr)
ud_may = usersPerBulan(ud_may)
ud_jun = usersPerBulan(ud_jun)
ud_jul = usersPerBulan(ud_jul)
ud_aug = usersPerBulan(ud_aug)
ud_sep = usersPerBulan(ud_sep)
ud_oct = usersPerBulan(ud_oct)
ud_nov = usersPerBulan(ud_nov)
ud_des = usersPerBulan(ud_des)

# %%
ud_month = [ud_jan, ud_feb, ud_mar, ud_apr, ud_may, ud_jun, ud_jul, ud_aug, ud_sep, ud_oct, ud_nov, ud_des]
print('User Donasi Before\n')
for i,x in enumerate(ud_month, start=1):
  print('bulan ke-',i,' jumlah hari', x['tanggal'].nunique())
# Out:
# User Donasi Before
#
# bulan ke- 1  jumlah hari 31
# bulan ke- 2  jumlah hari 28
# bulan ke- 3  jumlah hari 31
# bulan ke- 4  jumlah hari 30
# bulan ke- 5  jumlah hari 31
# bulan ke- 6  jumlah hari 30
# bulan ke- 7  jumlah hari 31
# bulan ke- 8  jumlah hari 31
# bulan ke- 9  jumlah hari 30
# bulan ke- 10  jumlah hari 31
# bulan ke- 11  jumlah hari 30
# bulan ke- 12  jumlah hari 6

# %%
# def fill_na_des(data,awal,akhir):
#   # idx_31 = pd.date_range('09-01-2020', '09-30-2020')
#   idx = pd.date_range(awal,akhir)
#   data.index = pd.DatetimeIndex(data.tanggal)
#   data = data.reindex(idx)
#   data = data.drop(['tanggal'], axis=1)
#   data = data.interpolate()
#   data = data.reset_index()
#   data = data.rename(columns={'index':'tanggal'})
#   return data

# # gd_des = fill_na_des(gd_des, '12-01-2021', '12-31-2021')

# %% [markdown]
# ## Donasi dataframe

# %%
# Guest Donasi DataFrame
df_gd = pd.concat(gd_month)

# Users Donasi DataFrame
df_ud = pd.concat(ud_month)

# %%
#Donasi
df_donasi = pd.concat([df_gd, df_ud], axis=0)
df_donasi = df_donasi.groupby(by='tanggal')['total_donasi'].sum().reset_index()
df_donasi
# Out:
#        tanggal  total_donasi
# 0   2021-01-01     9104921.0
# 1   2021-01-02    18147735.0
# 2   2021-01-03     4549815.0
# 3   2021-01-04     7592243.0
# 4   2021-01-05     5664702.0
# ..         ...           ...
# 335 2021-12-02     9457924.0
# 336 2021-12-03    21347947.0
# 337 2021-12-04     4513792.0
# 338 2021-12-05     3230000.0
# 339 2021-12-06     1040000.0
#
# [340 rows x 2 columns]

# %%
import plotly.graph_objs as go
fig = go.Figure(data=go.Scatter(x=df_donasi['tanggal'],
                                y=df_donasi['total_donasi'],
                                marker_color='red', text="total_donasi"))
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="b74dd392-66c5-499c-bb0f-ee603d558cd6" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("b74dd392-66c5-499c-bb0f-ee603d558cd6")) {
#                     Plotly.newPlot(
#                         'b74dd392-66c5-499c-bb0f-ee603d558cd6',
# ...

# %% [markdown]
# ###SMA

# %%
plt.rcParams["figure.figsize"] = (16,8)
donasi_arima = df_donasi.copy()
donasi_arima['7-days SMA'] = donasi_arima['total_donasi'].rolling(window=7).mean()
donasi_arima['30-days SMA'] = donasi_arima['total_donasi'].rolling(window=30).mean()
donasi_arima = donasi_arima.drop(['tanggal'], axis=1)
donasi_arima.plot()
plt.title('Donasi Forecast Simple Moving Average', fontsize=18)
plt.savefig('Donasi Forecast Simple Moving Average.png')
# plt.plot(test['tanggal'], test['total_donasi'])

# %% [markdown]
# ##SES

# %%
from statsmodels.tsa.holtwinters import SimpleExpSmoothing

donasi_ses = df_donasi.copy()

model_ses = SimpleExpSmoothing(df_donasi['total_donasi'])
fitted_model_ses = model_ses.fit(smoothing_level=0.3,optimized=False,use_brute=True) # bisa masukin alpha
donasi_ses['SES_0.3'] = fitted_model_ses.fittedvalues

fitted_model_ses = model_ses.fit(smoothing_level=0.8,optimized=False,use_brute=True) # bisa masukin alpha
donasi_ses['SES_0.8'] = fitted_model_ses.fittedvalues

donasi_ses.head()
# Out:
# /usr/local/lib/python3.7/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm
#      tanggal  total_donasi       SES_0.3       SES_0.8
# 0 2021-01-01     9104921.0  9.104921e+06  9.104921e+06
# 1 2021-01-02    18147735.0  9.104921e+06  9.104921e+06
# 2 2021-01-03     4549815.0  1.181777e+07  1.633917e+07
# 3 2021-01-04     7592243.0  9.637380e+06  6.907686e+06
# 4 2021-01-05     5664702.0  9.023839e+06  7.455332e+06

# %%
donasi_ses = donasi_ses.drop(['tanggal'], axis=1)
plt.rcParams["figure.figsize"] = (16,8)
donasi_ses.plot()
plt.title('Donasi Forecast Simple Exponential Smoothing', fontsize=18)
plt.savefig('Donasi Forecast Simple Exponential Smoothing.png')

# %%
plt.rcParams["figure.figsize"] = (16,8)
donasi_ses_wo_03 = donasi_ses.drop(['SES_0.3'], axis=1)
donasi_ses_wo_03.plot()
plt.title('Simple Exponential Smoothing with 0.8', fontsize=18)
# Out:
# Text(0.5, 1.0, 'Simple Exponential Smoothing with 0.8')

# %%
train_data = df_donasi.iloc[:280]
test_data = df_donasi.iloc[280:]

# %%
model_ses = SimpleExpSmoothing(train_data['total_donasi'])
fitted_model_ses = model_ses.fit(smoothing_level=0.8,optimized=False,use_brute=True)
ses_predict = fitted_model_ses.forecast(60)

# %%
train_data['total_donasi'].plot(legend=True, label = 'Train', figsize=(16,8))
test_data['total_donasi'].plot(legend=True, label = 'Test')
ses_predict.plot(legend=True, label = "Forecast")

# %% [markdown]
# ##Exp Smoothing

# %%
from statsmodels.tsa.holtwinters import ExponentialSmoothing

train_data = df_donasi.iloc[:280]
test_data = df_donasi.iloc[280:]

fitted_model = ExponentialSmoothing(train_data['total_donasi'], trend='add', seasonal_periods=7, seasonal='add').fit()
predict = fitted_model.forecast(60)

# %%
# from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
# import numpy as np

# for i in range(7,91):
#   fitted_model = ExponentialSmoothing(train_data['total_donasi'], trend='add', seasonal_periods=i, seasonal='add').fit()
#   predict = fitted_model.forecast(60)
#   print("ses period:",i,"R2: ",r2_score(test_data['total_donasi'],predict))

# %%
train_data['total_donasi'].plot(legend=True, label = 'Train', figsize=(16,8))
test_data['total_donasi'].plot(legend=True, label = 'Test')
predict.plot(legend=True, label = "Forecast")
plt.title('Donasi Forecast Exponential Smoothing', fontsize=18)
plt.savefig('Donasi Forecast Exponential Smoothing.png')

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
import numpy as np

print("Exponential Smoothing")
print("MAE: ",mean_absolute_error(test_data['total_donasi'],predict))
print("MSE: ",mean_squared_error(test_data['total_donasi'],predict))
print("RMSE: ", np.sqrt(mean_squared_error(test_data['total_donasi'],predict)))
print("R2: ",r2_score(test_data['total_donasi'],predict))
print("")
# Out:
# Exponential Smoothing
# MAE:  1918679.0701222469
# MSE:  6494090890813.864
# RMSE:  2548350.6216401746
# R2:  0.5341078964702866

# %%
donasi_performance_log = pd.DataFrame(columns=['experiment','MAE','MSE'])
MAE = mean_absolute_error(test_data['total_donasi'],predict)
MSE = mean_squared_error(test_data['total_donasi'],predict)
RMSE = np.sqrt(mean_squared_error(test_data['total_donasi'],predict))
R2 = r2_score(test_data['total_donasi'],predict)

perf = {
    'experiment': 'Exponential Smoothing',
    'MAE': MAE,
    'MSE': MSE,
    'RMSE': RMSE,
    'R2 score': R2,
    }

donasi_performance_log = donasi_performance_log.append(perf, ignore_index=True)
donasi_performance_log
# Out:
#               experiment           MAE           MSE  R2 score          RMSE
# 0  Exponential Smoothing  1.918679e+06  6.494091e+12  0.534108  2.548351e+06

# %% [markdown]
# ##Preproces Sarima

# %%
ts = df_donasi.copy()
ts.set_index('tanggal', inplace=True)
ts_log = ts['total_donasi']

# %%
ts_train = ts[:'2021-10-07']
ts_test = ts['2021-10-08':]

# %%
from statsmodels.tsa.seasonal import seasonal_decompose

result = seasonal_decompose(ts_log, model='additive',extrapolate_trend='freq')
plt.rcParams["figure.figsize"] = (16,8)
result.plot()
plt.show()

# %%
from statsmodels.tsa.stattools import adfuller
import numpy as np
ts = df_donasi.copy()
ts.set_index('tanggal', inplace=True)
ts_log = ts['total_donasi']
def check_stationarity(ts):
    dftest = adfuller(ts)
    adf = dftest[0]
    pvalue = dftest[1]
    critical_value = dftest[4]['5%']
    if (pvalue < 0.05) and (adf < critical_value):
        print('The series is stationary')
    else:
        print('The series is NOT stationary')

seasonal = result.seasonal
check_stationarity(seasonal)

# %%
seasonal = result.seasonal
check_stationarity(seasonal)
# Out:
# The series is stationary

# %%
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
plot_pacf(seasonal, lags =12)
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/statsmodels/regression/linear_model.py:1358: RuntimeWarning:
#
# invalid value encountered in sqrt

# %%
plot_acf(seasonal, lags =12)
plt.show()

# %% [markdown]
# ##ARIMA

# %%
from statsmodels.tsa.arima_model import ARIMA

# 1,1,2 ARIMA Model
model = ARIMA(train_data['total_donasi'], order=(1,1,0))
model_fit = model.fit(disp=-1)
arima_predict = model_fit.forecast(60)
print(model_fit.summary())
# Out:
#                              ARIMA Model Results
# ...
# Dep. Variable:         D.total_donasi   No. Observations:                  279
# Model:                 ARIMA(1, 1, 0)   Log Likelihood               -4786.815
# Method:                       css-mle   S.D. of innovations        6835675.563
# Date:                Fri, 21 Jan 2022   AIC                           9579.630
# Time:                        04:42:52   BIC                           9590.524
# Sample:                             1   HQIC                          9584.000
#
# ...
#                            coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                 -2.52e+04   2.79e+05     -0.090      0.928   -5.73e+05    5.23e+05
# ar.L1.D.total_donasi    -0.4660      0.053     -8.803      0.000      -0.570      -0.362
#                                     Roots
# ...

# %%
arima_series = pd.Series(arima_predict)
arima_series
# Out:
# 0    [2175530.1195734735, 2091745.1079216015, 20938...
# 1    [6835675.563369441, 7749260.044812932, 9296008...
# 2    [[-11222147.794631174, 15573208.033778122], [-...
# dtype: object

# %%
# arima_predict = model_fit.predict(280)
# arima_predict = arima_predict.reset_index(drop=True)
arima_series = pd.Series(arima_predict, index=test_data.index)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-88-b242a640b404> in <module>()
#       1 # arima_predict = model_fit.predict(280)
#       2 # arima_predict = arima_predict.reset_index(drop=True)
# ----> 3 arima_series = pd.Series(arima_predict, index=test_data.index)
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/series.py in __init__(self, data, index, dtype, name, copy, fastpath)
#     312                     if len(index) != len(data):
#     313                         raise ValueError(
# --> 314                             f"Length of passed values is {len(data)}, "
#     315                             f"index implies {len(index)}."
#     316                         )
#
# ValueError: Length of passed values is 3, index implies 60.

# %%
train_data['total_donasi'].plot(legend=True, label = 'Train', figsize=(16,8))
test_data['total_donasi'].plot(legend=True, label = 'Test')
arima_series.plot(legend=True, label = "Forecast")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-81-f805b38b6c44> in <module>()
#       1 train_data['total_donasi'].plot(legend=True, label = 'Train', figsize=(16,8))
#       2 test_data['total_donasi'].plot(legend=True, label = 'Test')
# ----> 3 arima_predict.plot(legend=True, label = "Forecast")
#
# AttributeError: 'tuple' object has no attribute 'plot'

# %%
model_fit.plot_predict(dynamic=False)
plt.show()

# %%
from statsmodels.tsa.statespace.sarimax import SARIMAX
d = 1
p = 1
q = 1

model = SARIMAX(ts_train, order=(p,d,q))
model_fit = model.fit()
# Out:
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/base/tsa_model.py:165: ValueWarning:
#
# No frequency information was provided, so inferred frequency D will be used.
#
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/statespace/sarimax.py:949: UserWarning:
#
# Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/statespace/sarimax.py:961: UserWarning:
#
# Non-invertible starting MA parameters found. Using zeros as starting parameters.
#
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/model.py:512: ConvergenceWarning:
#
# Maximum Likelihood optimization failed to converge. Check mle_retvals

# %%
n_test = ts_test.shape[0]
ts_pred = model_fit.forecast(steps=n_test)

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
import numpy as np

print("ARIMA")
print("MAE: ",mean_absolute_error(ts_test['total_donasi'],ts_pred))
print("MSE: ",mean_squared_error(ts_test['total_donasi'],ts_pred))
print("RMSE: ", np.sqrt(mean_squared_error(ts_test['total_donasi'],ts_pred)))
print("R2: ",r2_score(ts_test['total_donasi'],ts_pred))
print("")
# Out:
# SARIMAX
# MAE:  3884125.103898346
# MSE:  20049435901286.207
# RMSE:  4477659.64553875
# R2:  -0.3548273538074229

# %%
# from statsmodels.tsa.statespace.sarimax import SARIMAX
# model_seasonal = SARIMAX(ts_train, seasonal_order=(10,1,1,12))
# model_fit_seasonal = model_seasonal.fit()
# Out:
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/base/tsa_model.py:165: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   % freq, ValueWarning)

# %%
# n_test = ts_test.shape[0]
# ts_pred_seasonal = model_fit_seasonal.forecast(steps=n_test)
# print("SARIMAX")
# print("MAE: ",mean_absolute_error(ts_test['total_donasi'],ts_pred_seasonal))
# print("MSE: ",mean_squared_error(ts_test['total_donasi'],ts_pred_seasonal))
# print("RMSE: ", np.sqrt(mean_squared_error(ts_test['total_donasi'],ts_pred_seasonal)))
# print("R2: ",r2_score(ts_test['total_donasi'],ts_pred_seasonal))
# print("")
# Out:
# SARIMAX
# MAE:  3070340.7616801024
# MSE:  17359306582366.771
# RMSE:  4166450.1175901257
# R2:  -0.051074077953561225

# %%
ts_pred = model_fit.forecast(steps=n_test)
ts_pred_seasonal = model_fit_seasonal.forecast(steps=n_test)

# %%
plt.figure(figsize=(16,6))
plt.plot(ts_log, label='real values')
plt.plot(ts_pred_seasonal, label='prediction with P,D,Q')
plt.plot(ts_pred, label='prediction without P,D,Q')
#plt.plot(ts_test, label='actual')
plt.title('Multi-step Forecasting (manual parameters)')
plt.legend()
plt.grid()
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ##Machine Learning

# %%
df_ml = df_donasi.copy()
df_ml = df_ml.drop('tanggal', axis=1)
df_ml.head()
# Out:
#    total_donasi
# 0     9104921.0
# 1    18147735.0
# 2     4549815.0
# 3     7592243.0
# 4     5664702.0

# %%
#lagged Function, just copas from
#https://stackoverflow.com/questions/20410312/how-to-create-a-lagged-data-structure-using-pandas-dataframe
def LaggedFeatures(s,lag=2,fillna=True, dropna=False):
    if type(s) is pd.DataFrame:
        new_dict={}
        for col_name in s:
            new_dict[col_name]=s[col_name]
            # create lagged Series
            for l in range(1,lag+1):
                new_dict['%s_lag%d' %(col_name,l)]=s[col_name].shift(l)
        res=pd.DataFrame(new_dict,index=s.index)

    elif type(s) is pd.Series:
        the_range=range(lag+1)
        res=pd.concat([s.shift(i) for i in the_range],axis=1)
        res.columns=['lag_%d' %i for i in the_range]
    else:
        print ('Only works for DataFrame or Series')
        return None
    if dropna:
        res = res.dropna()
    else:
        res = res
    if fillna:
        return res.fillna(0)
    else:
        return res

# %%
lag_df = LaggedFeatures(df_ml, lag=7, fillna=True, dropna=True)
lag_df.head()
# Out:
#     total_donasi  total_donasi_lag1  ...  total_donasi_lag6  total_donasi_lag7
# 7     12493216.0          7127387.0  ...         18147735.0          9104921.0
# 8      2525627.0         12493216.0  ...          4549815.0         18147735.0
# 9      2811133.0          2525627.0  ...          7592243.0          4549815.0
# 10    11328655.0          2811133.0  ...          5664702.0          7592243.0
# 11     6396030.0         11328655.0  ...          4640977.0          5664702.0
#
# [5 rows x 8 columns]

# %%
train = lag_df.iloc[:273]
test = lag_df.iloc[273:]

# %%
X_train = train.drop("total_donasi", axis=1)
X_test = test.drop("total_donasi", axis=1)

y_train = train['total_donasi']
y_test = test['total_donasi']

X_train = X_train.astype(float).values
y_train = y_train.astype(float).values

X_test = X_test.astype(float).values
y_test = y_test.astype(float).values

# %%
#masukkan ke model regresi
from sklearn.svm import SVR #SVR
from sklearn.ensemble import RandomForestRegressor
from sklearn.neural_network import MLPRegressor
from sklearn.linear_model import LinearRegression
from sklearn.neighbors import KNeighborsRegressor

from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
import numpy as np

svr = SVR()
rf = RandomForestRegressor()
mlp = MLPRegressor(random_state=42)
lr = LinearRegression()
knr = KNeighborsRegressor(n_neighbors=14, weights='distance')

svr.fit(X_train, y_train)
rf.fit(X_train, y_train)
mlp.fit(X_train, y_train)
lr.fit(X_train, y_train)
knr.fit(X_train, y_train)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:696: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   ConvergenceWarning,
# KNeighborsRegressor(n_neighbors=14, weights='distance')

# %%
models = {
    'Linear Regression': LinearRegression(),
    'Random Forest': RandomForestRegressor(),
    'MLP Regressor': MLPRegressor(random_state=42),
    'KN Regressor': KNeighborsRegressor(n_neighbors=14, weights='distance'),
    'SV Regressor':SVR(),
}

for model_name, clf in models.items():
    clf.fit(X_train, y_train)
    y_pred = clf.predict(X_test)

    MAE = mean_absolute_error(y_test,y_pred)
    MSE = mean_squared_error(y_test,y_pred)
    RMSE = np.sqrt(mean_squared_error(y_test,y_pred))
    R2 = r2_score(y_test,y_pred)

    perf = {
    'experiment': model_name,
    'MAE': MAE,
    'MSE': MSE,
    'RMSE': RMSE,
    'R2 score': R2,
    }

    donasi_performance_log = donasi_performance_log.append(perf, ignore_index=True)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:696: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   ConvergenceWarning,

# %%
donasi_performance_log
# Out:
#               experiment           MAE           MSE  R2 score          RMSE
# 0  Exponential Smoothing  1.918679e+06  6.494091e+12  0.534108  2.548351e+06
# 1      Linear Regression  2.603113e+06  1.147117e+13  0.177047  3.386912e+06
# 2          Random Forest  2.249369e+06  7.685534e+12  0.448633  2.772280e+06
# 3          MLP Regressor  2.150299e+06  9.450474e+12  0.322014  3.074162e+06
# 4           KN Regressor  2.374384e+06  8.291087e+12  0.405190  2.879425e+06
# 5           SV Regressor  2.679361e+06  1.395585e+13 -0.001206  3.735753e+06

# %%
# for i in range(1,30):
#   knr = KNeighborsRegressor(n_neighbors=i, weights='distance')
#   knr.fit(X_train, y_train)
#   y_pred_knr = knr.predict(X_test)
#   print('nebor-',i,"R2: ",r2_score(y_test,y_pred_knr))

# %%
y_pred_svr = svr.predict(X_test)
y_pred_rf = rf.predict(X_test)
y_pred_mlp = mlp.predict(X_test)
y_pred_lr = lr.predict(X_test)
y_pred_knr = knr.predict(X_test)

# print("SVR")
# print("MAE: ",mean_absolute_error(y_test,y_pred_svr))
# print("MSE: ",mean_squared_error(y_test,y_pred_svr))
# print("RMSE: ", np.sqrt(mean_squared_error(y_test,y_pred_svr)))
# print("R2: ",r2_score(y_test,y_pred_svr))
# print("")

# print("RF")
# print("MAE: ",mean_absolute_error(y_test,y_pred_rf))
# print("MSE: ",mean_squared_error(y_test,y_pred_rf))
# print("RMSE: ", np.sqrt(mean_squared_error(y_test,y_pred_rf)))
# print("R2: ",r2_score(y_test,y_pred_rf))
# print("")

# print("MLP")
# print("MAE: ",mean_absolute_error(y_test,y_pred_mlp))
# print("MSE: ",mean_squared_error(y_test,y_pred_mlp))
# print("RMSE: ", np.sqrt(mean_squared_error(y_test,y_pred_mlp)))
# print("R2: ",r2_score(y_test,y_pred_mlp))
# print("")

# print("lr")
# print("MAE: ",mean_absolute_error(y_test,y_pred_lr))
# print("MSE: ",mean_squared_error(y_test,y_pred_lr))
# print("RMSE: ", np.sqrt(mean_squared_error(y_test,y_pred_lr)))
# print("R2: ",r2_score(y_test,y_pred_lr))
# print("")

# %%
y_test_df = pd.DataFrame(y_test, columns=["total_donasi"])


y_pred_rf_df = pd.DataFrame(y_pred_rf, columns=["Forecast"])
y_pred_mlp_df = pd.DataFrame(y_pred_mlp, columns=["Forecast"])
y_pred_lr_df = pd.DataFrame(y_pred_lr, columns=["Forecast"])
y_pred_knr_df = pd.DataFrame(y_pred_knr, columns=["Forecast"])
y_pred_svr_df = pd.DataFrame(y_pred_svr, columns=["Forecast"])

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(18,10))
plt.subplot(2,3,1)
plt.plot(y_test_df['total_donasi'], label='real')
plt.plot(y_pred_lr_df['Forecast'], label='forecast')
plt.title('Linear Regression')
plt.legend()

plt.subplot(2,3,2)
plt.plot(y_test_df['total_donasi'], label='real')
plt.plot(y_pred_mlp_df['Forecast'], label='forecast')
plt.title('MLP Regressor')
plt.legend()

plt.subplot(2,3,3)
plt.plot(y_test_df['total_donasi'], label='real')
plt.plot(y_pred_rf_df['Forecast'], label='forecast')
plt.title('RF Regressor')
plt.legend()

plt.subplot(2,3,4)
plt.plot(y_test_df['total_donasi'], label='real')
plt.plot(y_pred_knr_df['Forecast'], label='forecast')
plt.title('KN Regressor')
plt.legend()

plt.subplot(2,3,5)
plt.plot(y_test_df['total_donasi'], label='real')
plt.plot(y_pred_svr_df['Forecast'], label='forecast')
plt.title('SV Regressor')
plt.legend()

plt.suptitle('Model Data Donasi', fontsize=18)
# Out:
# Text(0.5, 0.98, 'Model Data Donasi')

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(18,5))
plt.subplot(1,3,1)
test_data['total_donasi'].plot(legend=True, label = 'real')
predict.plot(legend=True, label = "Forecast")
plt.title('Exponential Smoothing')
plt.legend()

plt.subplot(1,3,2)
plt.plot(y_test_df['total_donasi'], label='real')
plt.plot(y_pred_mlp_df['Forecast'], label='forecast')
plt.title('MLP Regressor')
plt.legend()

plt.subplot(1,3,3)
plt.plot(y_test_df['total_donasi'], label='real')
plt.plot(y_pred_rf_df['Forecast'], label='forecast')
plt.title('RF Regressor')
plt.legend()

plt.suptitle('3 Best Model Donasi Forecast', fontsize=18)
plt.savefig('3 Best Model Donasi Forecast')

# %% [markdown]
# #Data Zakat

# %%
def guestPerBulan_zakat(data):
  data = data.copy()
  data = data.drop(['ID', 'nama_lengkap', 'platform', 'category', 'status', 'metode_pembayaran'], axis=1)
  data['tanggal'] = data['tanggal'].str.slice(start=0, stop=10)
  data = data.groupby('tanggal')['total_zakat'].sum().reset_index()
  data = data.sort_values(by='tanggal', ascending=True)
  data.index = pd.DatetimeIndex(data.tanggal)
  data = data.drop(['tanggal'], axis=1)
  data = data.reset_index()
  data = data.rename(columns={'index':'tanggal'})
  return data

def usersPerBulan_zakat(data):
  data = data.copy()
  data = data.drop(['ID', 'name', 'platform', 'category', 'status', 'metode_pembayaran'], axis=1)
  data['tanggal'] = data['tanggal'].str.slice(start=0, stop=10)
  data = data.groupby('tanggal')['total_zakat'].sum().reset_index()
  data = data.sort_values(by='tanggal', ascending=True)
  data.index = pd.DatetimeIndex(data.tanggal)
  data = data.drop(['tanggal'], axis=1)
  data = data.reset_index()
  data = data.rename(columns={'index':'tanggal'})
  return data

# %%
df_gz = guestPerBulan_zakat(df_gz)

# %%
uz_jan = usersPerBulan_zakat(uz_jan)
uz_feb = usersPerBulan_zakat(uz_feb)
uz_mar = usersPerBulan_zakat(uz_mar)
uz_apr = usersPerBulan_zakat(uz_apr)
uz_may = usersPerBulan_zakat(uz_may)
uz_jun = usersPerBulan_zakat(uz_jun)
uz_jul = usersPerBulan_zakat(uz_jul)
uz_aug = usersPerBulan_zakat(uz_aug)
uz_sep = usersPerBulan_zakat(uz_sep)
uz_oct = usersPerBulan_zakat(uz_oct)
uz_nov = usersPerBulan_zakat(uz_nov)
uz_des = usersPerBulan_zakat(uz_des)

# %%
uz_month = [uz_jan, uz_feb, uz_mar, uz_apr, uz_may, uz_jun, uz_jul, uz_aug, uz_sep, uz_oct, uz_nov, uz_des]
print('User Zakat Before\n')
for i,x in enumerate(uz_month, start=1):
  print('bulan ke-',i,' jumlah hari', x['tanggal'].nunique())
# Out:
# User Zakat Before
#
# bulan ke- 1  jumlah hari 22
# bulan ke- 2  jumlah hari 21
# bulan ke- 3  jumlah hari 9
# bulan ke- 4  jumlah hari 10
# bulan ke- 5  jumlah hari 13
# bulan ke- 6  jumlah hari 10
# bulan ke- 7  jumlah hari 11
# bulan ke- 8  jumlah hari 15
# bulan ke- 9  jumlah hari 16
# bulan ke- 10  jumlah hari 23
# bulan ke- 11  jumlah hari 22
# bulan ke- 12  jumlah hari 5

# %% [markdown]
# ##Fill NaN Data Zakat

# %%
def fill_na(data,awal,akhir):
  # idx_31 = pd.date_range('09-01-2020', '09-30-2020')
  idx = pd.date_range(awal,akhir)
  data.index = pd.DatetimeIndex(data.tanggal)
  data = data.reindex(idx)
  data = data.drop(['tanggal'], axis=1)
  data = data.fillna(method='ffill')
  data = data.reset_index()
  data = data.rename(columns={'index':'tanggal'})
  return data

# %%
uz_jan = fill_na(uz_jan, '01-01-2021', '01-31-2021')
uz_feb = fill_na(uz_feb, '02-01-2021', '02-28-2021')
uz_mar = fill_na(uz_mar, '03-01-2021', '03-31-2021')
uz_apr = fill_na(uz_apr, '04-01-2021', '04-30-2021')
uz_may = fill_na(uz_may, '05-01-2021', '05-31-2021')
uz_jun = fill_na(uz_jun, '06-01-2021', '06-30-2021')
uz_jul = fill_na(uz_jul, '07-01-2021', '07-31-2021')
uz_aug = fill_na(uz_aug, '08-01-2021', '08-31-2021')
uz_sep = fill_na(uz_sep, '09-01-2021', '09-30-2021')
uz_oct = fill_na(uz_oct, '10-01-2021', '10-31-2021')
uz_nov = fill_na(uz_nov, '11-01-2021', '11-30-2021')

# %%
uz_month = [uz_jan, uz_feb, uz_mar, uz_apr, uz_may, uz_jun, uz_jul, uz_aug, uz_sep, uz_oct, uz_nov, uz_des]
print('User Zakat After\n')
for i,x in enumerate(uz_month, start=1):
  print('bulan ke-',i,' jumlah hari', x['tanggal'].nunique())
# Out:
# User Zakat After
#
# bulan ke- 1  jumlah hari 31
# bulan ke- 2  jumlah hari 28
# bulan ke- 3  jumlah hari 31
# bulan ke- 4  jumlah hari 30
# bulan ke- 5  jumlah hari 31
# bulan ke- 6  jumlah hari 30
# bulan ke- 7  jumlah hari 31
# bulan ke- 8  jumlah hari 31
# bulan ke- 9  jumlah hari 30
# bulan ke- 10  jumlah hari 31
# bulan ke- 11  jumlah hari 30
# bulan ke- 12  jumlah hari 5

# %% [markdown]
# ##Concate Dataframe

# %%
# Users Donasi DataFrame
df_uz = pd.concat(uz_month)

# %%
df_zakat = pd.concat([df_gz, df_uz], axis=0)
df_zakat = df_zakat.groupby(by='tanggal')['total_zakat'].sum().reset_index()
df_zakat
# Out:
#        tanggal  total_zakat
# 0   2021-01-01    6000000.0
# 1   2021-01-02    6000000.0
# 2   2021-01-03    6000000.0
# 3   2021-01-04    7127500.0
# 4   2021-01-05     650000.0
# ..         ...          ...
# 334 2021-12-01    1929000.0
# 335 2021-12-02    1845000.0
# 336 2021-12-03     963000.0
# 337 2021-12-04     100000.0
# 338 2021-12-05     900000.0
#
# [339 rows x 2 columns]

# %%
from statsmodels.tsa.stattools import adfuller
from statsmodels.tsa.seasonal import seasonal_decompose
import numpy as np

ts = df_zakat.copy()
ts.set_index('tanggal', inplace=True)
ts_log = ts['total_zakat']
result = seasonal_decompose(ts_log, model='additive',extrapolate_trend='freq')

seasonal = result.seasonal
check_stationarity(seasonal)
# Out:
# The series is stationary

# %%
import plotly.graph_objs as go
fig = go.Figure(data=go.Scatter(x=df_zakat['tanggal'],
                                y=df_zakat['total_zakat'],
                                marker_color='red', text="total_zakat"))
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="3db33f1a-144e-46d3-ad6e-d0bc41fb5f18" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("3db33f1a-144e-46d3-ad6e-d0bc41fb5f18")) {
#                     Plotly.newPlot(
#                         '3db33f1a-144e-46d3-ad6e-d0bc41fb5f18',
# ...

# %% [markdown]
# ##SMA

# %%
plt.rcParams["figure.figsize"] = (16,8)
zakat_sma = df_zakat.copy()
zakat_sma['7-days SMA'] = zakat_sma['total_zakat'].rolling(window=7).mean()
zakat_sma['30-days SMA'] = zakat_sma['total_zakat'].rolling(window=30).mean()
zakat_sma = zakat_sma.drop(['tanggal'], axis=1)
zakat_sma.plot()
plt.title(' Zakat Forecast Simple Moving Average', fontsize=18)
plt.savefig('Zakat Forecast Simple Moving Average.png')

# %% [markdown]
# SES

# %%
zakat_ses = df_zakat.copy()

model_ses = SimpleExpSmoothing(df_zakat['total_zakat'])
fitted_model_ses = model_ses.fit(smoothing_level=0.3,optimized=False,use_brute=True) # bisa masukin alpha
zakat_ses['SES_0.3'] = fitted_model_ses.fittedvalues

fitted_model_ses = model_ses.fit(smoothing_level=0.8,optimized=False,use_brute=True) # bisa masukin alpha
zakat_ses['SES_0.8'] = fitted_model_ses.fittedvalues

zakat_ses.head()
# Out:
#      tanggal  total_zakat    SES_0.3    SES_0.8
# 0 2021-01-01    6000000.0  6000000.0  6000000.0
# 1 2021-01-02    6000000.0  6000000.0  6000000.0
# 2 2021-01-03    6000000.0  6000000.0  6000000.0
# 3 2021-01-04    7127500.0  6000000.0  6000000.0
# 4 2021-01-05     650000.0  6338250.0  6902000.0

# %%
zakat_ses = zakat_ses.drop(['tanggal'], axis=1)
plt.rcParams["figure.figsize"] = (16,8)
zakat_ses.plot()
plt.title('Zakat Forecast Simple Exponential Smoothing', fontsize=18)
plt.savefig('Zakat Forecast Simple Exponential Smoothing.png')

# %%
plt.rcParams["figure.figsize"] = (16,8)
zakat_ses_wo_03 = zakat_ses.drop(['SES_0.3'], axis=1)
zakat_ses_wo_03.plot()
plt.title('Forecast Simple Exponential Smoothing with 0.8', fontsize=18)
# Out:
# Text(0.5, 1.0, 'Forecast Simple Exponential Smoothing with 0.8')

# %% [markdown]
# ES

# %%
from statsmodels.tsa.holtwinters import ExponentialSmoothing

zakat_train_data = df_zakat.iloc[:279]
zakat_test_data = df_zakat.iloc[279:]

fitted_model_es = ExponentialSmoothing(zakat_train_data['total_zakat'], trend='add', seasonal_periods=26, seasonal='add').fit()
es_predict = fitted_model_es.forecast(60)

# %%
# from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
# import numpy as np

# for i in range(7,91):
#   fitted_model_es = ExponentialSmoothing(zakat_train_data['total_zakat'], trend='add', seasonal_periods=i, seasonal='add').fit()
#   es_predict = fitted_model_es.forecast(60)
#   print("ses period:",i,"R2: ",r2_score(zakat_test_data['total_zakat'],es_predict))

# %%
zakat_train_data['total_zakat'].plot(legend=True, label = 'Train', figsize=(16,8))
zakat_test_data['total_zakat'].plot(legend=True, label = 'Test')
es_predict.plot(legend=True, label = "Forecast")
plt.title('Zakat Forecast Exponential Smoothing', fontsize=18)
plt.savefig('Zakat Forecast Exponential Smoothing.png')

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
import numpy as np

print("Exponential Smoothing")
print("MAE: ",mean_absolute_error(zakat_test_data['total_zakat'],es_predict))
print("MSE: ",mean_squared_error(zakat_test_data['total_zakat'],es_predict))
print("RMSE: ", np.sqrt(mean_squared_error(zakat_test_data['total_zakat'],es_predict)))
print("R2: ",r2_score(zakat_test_data['total_zakat'],es_predict))
print("")
# Out:
# Exponential Smoothing
# MAE:  1404310.355379509
# MSE:  5837946647878.128
# RMSE:  2416184.3157917666
# R2:  0.032877086039835635

# %%
performance_log = pd.DataFrame(columns=['experiment','MAE','MSE'])
MAE = mean_absolute_error(zakat_test_data['total_zakat'],es_predict)
MSE = mean_squared_error(zakat_test_data['total_zakat'],es_predict)
RMSE = np.sqrt(mean_squared_error(zakat_test_data['total_zakat'],es_predict))
R2 = r2_score(zakat_test_data['total_zakat'],es_predict)

perf = {
    'experiment': 'Exponential Smoothing',
    'MAE': MAE,
    'MSE': MSE,
    'RMSE': RMSE,
    'R2 score': R2,
    }

performance_log = performance_log.append(perf, ignore_index=True)
performance_log
# Out:
#               experiment           MAE           MSE  R2 score          RMSE
# 0  Exponential Smoothing  1.404310e+06  5.837947e+12  0.032877  2.416184e+06

# %% [markdown]
# ##Machine Learning

# %%
df_ml = df_zakat.copy()
df_ml = df_ml.drop('tanggal', axis=1)
df_ml.head()
# Out:
#    total_zakat
# 0    6000000.0
# 1    6000000.0
# 2    6000000.0
# 3    7127500.0
# 4     650000.0

# %%
lag_df = LaggedFeatures(df_ml, lag=7, fillna=True, dropna=True)
lag_df.head()
# Out:
#     total_zakat  total_zakat_lag1  ...  total_zakat_lag6  total_zakat_lag7
# 7      700000.0         4370232.0  ...         6000000.0         6000000.0
# 8     1250000.0          700000.0  ...         6000000.0         6000000.0
# 9      250000.0         1250000.0  ...         7127500.0         6000000.0
# 10    1200000.0          250000.0  ...          650000.0         7127500.0
# 11    1000000.0         1200000.0  ...         1525000.0          650000.0
#
# [5 rows x 8 columns]

# %%
df_zakat.shape
# Out:
# (339, 2)

# %%
train = lag_df.iloc[:272]
test = lag_df.iloc[272:]

# %%
X_train = train.drop("total_zakat", axis=1)
X_test = test.drop("total_zakat", axis=1)

y_train = train['total_zakat']
y_test = test['total_zakat']

X_train = X_train.astype(float).values
y_train = y_train.astype(float).values

X_test = X_test.astype(float).values
y_test = y_test.astype(float).values

# %%
from sklearn.neighbors import KNeighborsRegressor
from sklearn.linear_model import Ridge
svr = SVR()
rf = RandomForestRegressor()
mlp = MLPRegressor(random_state=40)
lr = LinearRegression()
knr = KNeighborsRegressor(n_neighbors=20, weights='distance')
ridge = Ridge()

svr.fit(X_train, y_train)
rf.fit(X_train, y_train)
mlp.fit(X_train, y_train)
lr.fit(X_train, y_train)
knr.fit(X_train, y_train)
ridge.fit(X_train, y_train)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:696: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   ConvergenceWarning,
# Ridge()

# %%
models = {
    'Linear Regression': LinearRegression(),
    'Random Forest': RandomForestRegressor(),
    'MLP Regressor': MLPRegressor(random_state=40),
    'KN Regressor': KNeighborsRegressor(n_neighbors=20, weights='distance'),
    'SV Regressor':SVR(),
}

for model_name, clf in models.items():
    clf.fit(X_train, y_train)
    y_pred = clf.predict(X_test)

    MAE = mean_absolute_error(y_test,y_pred)
    MSE = mean_squared_error(y_test,y_pred)
    RMSE = np.sqrt(mean_squared_error(y_test,y_pred))
    R2 = r2_score(y_test,y_pred)

    perf = {
    'experiment': model_name,
    'MAE': MAE,
    'MSE': MSE,
    'RMSE': RMSE,
    'R2 score': R2,
    }

    performance_log = performance_log.append(perf, ignore_index=True)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:696: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   ConvergenceWarning,

# %%
performance_log
# Out:
#               experiment           MAE           MSE  R2 score          RMSE
# 0  Exponential Smoothing  1.404310e+06  5.837947e+12  0.032877  2.416184e+06
# 1      Linear Regression  1.241462e+06  5.660562e+12  0.062263  2.379194e+06
# 2          Random Forest  1.155380e+06  4.685577e+12  0.223780  2.164619e+06
# 3          MLP Regressor  1.230733e+06  5.420770e+12  0.101987  2.328255e+06
# 4           KN Regressor  1.258665e+06  5.207966e+12  0.137241  2.282097e+06
# 5           SV Regressor  1.247500e+06  7.382506e+12 -0.222997  2.717077e+06

# %%
y_pred_svr = svr.predict(X_test)
y_pred_rf = rf.predict(X_test)
y_pred_mlp = mlp.predict(X_test)
y_pred_lr = lr.predict(X_test)
y_pred_knr = knr.predict(X_test)
y_pred_ridge = ridge.predict(X_test)

# print("SVR")
# print("MAE: ",mean_absolute_error(y_test,y_pred_svr))
# print("MSE: ",mean_squared_error(y_test,y_pred_svr))
# print("RMSE: ", np.sqrt(mean_squared_error(y_test,y_pred_svr)))
# print("R2: ",r2_score(y_test,y_pred_svr))
# print("")

# print("RF")
# print("MAE: ",mean_absolute_error(y_test,y_pred_rf))
# print("MSE: ",mean_squared_error(y_test,y_pred_rf))
# print("RMSE: ", np.sqrt(mean_squared_error(y_test,y_pred_rf)))
# print("R2: ",r2_score(y_test,y_pred_rf))
# print("")

# print("MLP")
# print("MAE: ",mean_absolute_error(y_test,y_pred_mlp))
# print("MSE: ",mean_squared_error(y_test,y_pred_mlp))
# print("RMSE: ", np.sqrt(mean_squared_error(y_test,y_pred_mlp)))
# print("R2: ",r2_score(y_test,y_pred_mlp))
# print("")

# print("lr")
# print("MAE: ",mean_absolute_error(y_test,y_pred_lr))
# print("MSE: ",mean_squared_error(y_test,y_pred_lr))
# print("RMSE: ", np.sqrt(mean_squared_error(y_test,y_pred_lr)))
# print("R2: ",r2_score(y_test,y_pred_lr))
# print("")

# print("KNR")
# print("MAE: ",mean_absolute_error(y_test,y_pred_knr))
# print("MSE: ",mean_squared_error(y_test,y_pred_knr))
# print("RMSE: ", np.sqrt(mean_squared_error(y_test,y_pred_knr)))
# print("R2: ",r2_score(y_test,y_pred_knr))
# print("")

# print("Ridge")
# print("MAE: ",mean_absolute_error(y_test,y_pred_ridge))
# print("MSE: ",mean_squared_error(y_test,y_pred_ridge))
# print("RMSE: ", np.sqrt(mean_squared_error(y_test,y_pred_ridge)))
# print("R2: ",r2_score(y_test,y_pred_ridge))
# print("")

# %%
y_test_df = pd.DataFrame(y_test, columns=["total_zakat"])


y_pred_rf_df = pd.DataFrame(y_pred_rf, columns=["Forecast"])
y_pred_mlp_df = pd.DataFrame(y_pred_mlp, columns=["Forecast"])
y_pred_knr_df = pd.DataFrame(y_pred_knr, columns=["Forecast"])

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(18,5))
plt.subplot(1,3,1)
plt.plot(y_test_df['total_zakat'], label='real')
plt.plot(y_pred_mlp_df['Forecast'], label='forecast')
plt.title('MLP Regressor')
plt.legend()

plt.subplot(1,3,2)
plt.plot(y_test_df['total_zakat'], label='real')
plt.plot(y_pred_knr_df['Forecast'], label='forecast')
plt.title('KNN Regressor')
plt.legend()

plt.subplot(1,3,3)
plt.plot(y_test_df['total_zakat'], label='real')
plt.plot(y_pred_rf_df['Forecast'], label='forecast')
plt.title('RF Regressor')
plt.legend()

plt.suptitle('3 Best Model Zakat Forecast')
plt.savefig('3 Best Model Zakat Forecast.png')

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(18,5))
plt.subplot(1,3,1)
plt.plot(y_test_df['total_zakat'], label='real')
plt.plot(y_pred_lr_df['Forecast'], label='forecast')
plt.title('Linear Regression')
plt.legend()

plt.subplot(1,3,2)
plt.plot(y_test_df['total_zakat'], label='real')
plt.plot(y_pred_knr_df['Forecast'], label='forecast')
plt.title('KNN Regressor')
plt.legend()

plt.subplot(1,3,3)
plt.plot(y_test_df['total_zakat'], label='real')
plt.plot(y_pred_rf_df['Forecast'], label='forecast')
plt.title('RF Regressor')
plt.legend()

plt.suptitle('Model Data Zakat', fontsize='18')
# Out:
# Text(0.5, 0.98, 'Model Data Zakat')

# %% [markdown]
# ##Check data Zakat per Bulan

# %%
def guestPerBulan_zakat(data):
  data = data.copy()
  data = data.drop(['ID', 'nama_lengkap', 'platform', 'category', 'status', 'metode_pembayaran'], axis=1)
  data['tanggal'] = data['tanggal'].str.slice(start=0, stop=10)
  data = data.groupby('tanggal')['total_zakat'].sum().reset_index()
  data = data.sort_values(by='tanggal', ascending=True)
  # data.index = pd.DatetimeIndex(data.tanggal)
  # data = data.drop(['tanggal'], axis=1)
  return data

def usersPerBulan_zakat(data):
  data = data.copy()
  data = data.drop(['ID', 'name', 'platform', 'category', 'status', 'metode_pembayaran'], axis=1)
  data['tanggal'] = data['tanggal'].str.slice(start=0, stop=10)
  data = data.groupby('tanggal')['total_zakat'].sum().reset_index()
  data = data.sort_values(by='tanggal', ascending=True)
  return data

# %%
test = guestPerBulan_zakat(df_gz)
test['tanggal']
# Out:
# 0     2021-01-05
# 1     2021-01-06
# 2     2021-01-07
# 3     2021-01-09
# 4     2021-01-18
#          ...
# 62    2021-11-28
# 63    2021-11-29
# 64    2021-11-30
# 65    2021-12-02
# 66    2021-12-03
# Name: tanggal, Length: 67, dtype: object

# %% [markdown]
# guest zakat

# %%
df_gz = guestPerBulan_zakat(df_gz)
df_gz = df_gz.groupby(by='tanggal')['total_zakat'].sum().reset_index()
plt.rcParams["figure.figsize"] = (16,8)
plt.plot(df_gz['tanggal'], df_gz['total_zakat'])

# %% [markdown]
# user zakat

# %%
uz_jan = usersPerBulan_zakat(uz_jan)
uz_feb = usersPerBulan_zakat(uz_feb)
uz_mar = usersPerBulan_zakat(uz_mar)
uz_apr = usersPerBulan_zakat(uz_apr)
uz_may = usersPerBulan_zakat(uz_may)
uz_jun = usersPerBulan_zakat(uz_jun)
uz_jul = usersPerBulan_zakat(uz_jul)
uz_aug = usersPerBulan_zakat(uz_aug)
uz_sep = usersPerBulan_zakat(uz_sep)
uz_oct = usersPerBulan_zakat(uz_oct)
uz_nov = usersPerBulan_zakat(uz_nov)
uz_des = usersPerBulan_zakat(uz_des)

# %%
uz_jan.shape
# Out:
# (22, 2)

# %%
uz_list_frames = [uz_jan, uz_feb, uz_mar, uz_apr, uz_may, uz_jun, uz_jul, uz_aug, uz_sep, uz_oct, uz_nov, uz_des]
print('User Zakat Before\n')
for i,x in enumerate(uz_list_frames, start=1):
  print('bulan ke-',i,' jumlah hari', x['tanggal'].nunique())
# Out:
# User Zakat Before
#
# bulan ke- 1  jumlah hari 22
# bulan ke- 2  jumlah hari 21
# bulan ke- 3  jumlah hari 9
# bulan ke- 4  jumlah hari 10
# bulan ke- 5  jumlah hari 13
# bulan ke- 6  jumlah hari 10
# bulan ke- 7  jumlah hari 11
# bulan ke- 8  jumlah hari 15
# bulan ke- 9  jumlah hari 16
# bulan ke- 10  jumlah hari 23
# bulan ke- 11  jumlah hari 22
# bulan ke- 12  jumlah hari 5

# %%
uz_des['tanggal']
# Out:
# 0    2021-12-01
# 1    2021-12-02
# 2    2021-12-03
# 3    2021-12-04
# 4    2021-12-05
# Name: tanggal, dtype: object

# %%
uz_list_frames = [uz_jan, uz_feb, uz_mar, uz_apr, uz_may, uz_jun, uz_jul, uz_aug, uz_sep, uz_oct, uz_nov, uz_des]
# df_uz = pd.concat(uz_list_frames)
plt.rcParams["figure.figsize"] = (16,8)
plt.plot(df_uz['tanggal'], df_uz['total_zakat'])

# %% [markdown]
# ##Concat DataFrame

# %%
# Guest Donasi DataFrame
gd_list_frames = [gd_jan, gd_feb, gd_mar, gd_apr, gd_may, gd_jun, gd_jul, gd_aug, gd_sep, gd_oct, gd_nov, gd_des]
df_gd = pd.concat(gd_list_frames)

# Users Donasi DataFrame
ud_list_frames = [ud_jan, ud_feb, ud_mar, ud_apr, ud_may, ud_jun, ud_jul, ud_aug, ud_sep, ud_oct, ud_nov, ud_des]
df_ud = pd.concat(ud_list_frames)

# %% [markdown]
# #Donasi

# %%
df_donasi = pd.concat([df_gd, df_ud], axis=0) #menggabungkan data guest dan data users

# %%
train_df = df_donasi[['tanggal', 'total_donasi']]
train_df['year'] = pd.to_datetime(df_donasi['tanggal']).dt.year
train_df['month'] = pd.to_datetime(df_donasi['tanggal']).dt.month
train_df['day'] = pd.to_datetime(df_donasi['tanggal']).dt.day
train_df['day_of_week'] = pd.to_datetime(df_donasi['tanggal']).dt.day_name()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
train_df[-12:]
# Out:
#         tanggal  total_donasi  year  month  day day_of_week
# 127  2021-12-06         20000  2021     12    6      Monday
# 128  2021-12-06        100000  2021     12    6      Monday
# 129  2021-12-06        200000  2021     12    6      Monday
# 130  2021-12-06         10000  2021     12    6      Monday
# 131  2021-12-06        150000  2021     12    6      Monday
# 127  2021-12-06         20000  2021     12    6      Monday
# 128  2021-12-06         20000  2021     12    6      Monday
# 129  2021-12-06         20000  2021     12    6      Monday
# 130  2021-12-06         20000  2021     12    6      Monday
# 131  2021-12-06         20000  2021     12    6      Monday
# 126  2021-12-06         50000  2021     12    6      Monday
# 132  2021-12-06        100000  2021     12    6      Monday

# %%
df_donasi_monthly = df_donasi[['tanggal', 'total_donasi']]
df_donasi_monthly['tanggal'] = df_donasi_monthly['tanggal'].apply(lambda x: str(x)[:-3])
df_donasi_monthly = df_donasi_monthly.groupby('tanggal')['total_donasi'].sum().reset_index()
df_donasi_monthly.date = pd.to_datetime(df_donasi_monthly.tanggal)

plt.rcParams["figure.figsize"] = (16,8)
plt.plot(df_donasi_monthly['tanggal'], df_donasi_monthly['total_donasi'])
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:4: UserWarning:
#
# Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access

# %%
plt.rcParams["figure.figsize"] = (16,8)
test = df_donasi[['tanggal', 'total_donasi']].groupby('tanggal').mean().reset_index()
test['7-days SMA'] = test['total_donasi'].rolling(window=4).mean()
test['30-days SMA'] = test['total_donasi'].rolling(window=30).mean()
test.plot()
# plt.plot(test['tanggal'], test['total_donasi'])

# %%
df_donasi.shape
# Out:
# (9081, 9)

# %%
from statsmodels.tsa.holtwinters import SimpleExpSmoothing
df_ses = df_donasi[['tanggal', 'total_donasi']].iloc[:750].groupby('tanggal').sum().reset_index()

from statsmodels.tsa.stattools import adfuller
ADF_result = adfuller(test.total_donasi)
print(f'ADF Statistic: {ADF_result[0]}')
print(f'p-value: {ADF_result[1]}')

# model_ses = SimpleExpSmoothing(df_ses['total_donasi'].astype(float))
# fitted_model_ses = model_ses.fit(smoothing_level = 0.8, use_brute = True, optimized = False)
# df_ses["alpa_0.6"] = fitted_model_ses.fittedvalues

# fitted_model_ses = model_ses.fit(smoothing_level = 0.9, use_brute = True, optimized = False)
# df_ses["alpa_0.7"] = fitted_model_ses.fittedvalues
# df_ses.plot()
# Out:
# ADF Statistic: -6.067285016944675
# p-value: 1.1735130650932078e-07

# %%
df_ses
# Out:
#       tanggal  total_donasi     alpa_0.3     alpa_0.8
# 0  2021-01-01       9104921   9104921.00   9104921.00
# 1  2021-01-02      18147735   9104921.00   9104921.00
# 2  2021-01-03       4549815  11817765.20  16339172.20
# 3  2021-01-04       3550743   9637380.14   6907686.44

# %%
import plotly.graph_objs as go
fig = go.Figure(data=go.Scatter(x=test['tanggal'],
                                y=test['total_donasi'],
                                marker_color='red', text="total_donasi"))
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="80d8df1e-d762-48f0-a7dc-c0b1fa723863" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("80d8df1e-d762-48f0-a7dc-c0b1fa723863")) {
#                     Plotly.newPlot(
#                         '80d8df1e-d762-48f0-a7dc-c0b1fa723863',
# ...

# %% [markdown]
# # Data Zakat

# %%
df_zakat = pd.concat([df_gz, df_uz], axis=0) #menggabungkan data guest dan data users
df_zakat['platform'] = df_zakat['platform'].replace(['WEB'], 'Web') #menyamakan format nama
df_zakat['total_donasi'] = df_zakat['total_zakat'].astype('Int64') #mengubah format menjadi int
df_zakat = df_zakat.sort_values(by='tanggal', ascending=True)

# %%
df_zakat
# Out:
#        ID                nama_lengkap  ... status_user total_donasi
# 0    2689  Dirga Imam Gozali Sumantri  ...        user      6000000
# 1    2690    Putu Berly Calvina Izumi  ...        user       100000
# 2    2691          Pak Saeful Rokhman  ...        user       300000
# 3    2692    Vinanda Langgeng Kencana  ...        user      1000000
# 4    2693                      Novias  ...        user        55000
# ..    ...                         ...  ...         ...          ...
# 8    4032   Libonit Poetry Mayangsari  ...        user       250000
# 337  4033                       ninis  ...       guest       213000
# 9    4034              Nike Pudjiwati  ...        user       100000
# 10   4035               Helena Shinta  ...        user       500000
# 11   4036               Ima Gusnandar  ...        user       400000
#
# [675 rows x 10 columns]
